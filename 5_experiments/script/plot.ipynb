# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the .npy file
file_path = "/mnt/UIT-Together/VitFromScratch/timm/checkpoints/v1_pz16-img224-h12-d12-hd768-2/metrics/training_accuracies.npy"
data = np.load(file_path)

# Plot the data
plt.plot(data)
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
